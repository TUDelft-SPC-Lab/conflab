# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import matplotlib.pyplot as plt

# %%
from conflab.constants import (
    raw_ss_path,
    processed_ss_path
)
from conflab.preprocessing.tools import interpolate
from conflab.preprocessing.speaking_status.utils import (
    read_labels, preprocess_labels_in_place, join_labels,
    write_csv_labels)

# %%
labels = read_labels(raw_ss_path)
preprocess_labels_in_place(labels)
    # write_csv_labels(labels, args.processed_labels_path)
# Out:
# 8it [00:04,  1.87it/s]
# 100%|██████████| 8/8 [00:00<00:00,  8.36it/s]

# %%
speaking, confidence = join_labels(labels)

# %%
speaking.to_csv(os.path.join(processed_ss_path, 'speaking.csv'), index=False)
confidence.to_csv(os.path.join(processed_ss_path, 'confidence.csv'), index=False)

# %%
sample = labels['vid2_seg8'][1]['ss']

# %%
plt.plot(sample['data0'][-1000:-800])

# %%
interpolated = interpolate(sample, method='nearest', axis=0)

# %%
plt.plot(sample['data0'])

# %%
plt.plot(interpolated['data0'])
